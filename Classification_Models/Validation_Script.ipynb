# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# !ls -lt '/content/gdrive/My Drive/' 
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, MaxPooling1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import binary_accuracy, AUC
from sklearn.utils import shuffle
# Out:
# Mounted at /content/gdrive
# total 6698731
# -rw------- 1 root root        107 Jan 16 13:59  checkpoint
# -rw------- 1 root root   12803838 Jan 16 13:59  BBH_Classification_5.ckpt.data-00000-of-00001
# -rw------- 1 root root       3268 Jan 16 13:59  BBH_Classification_5.ckpt.index
# -rw------- 1 root root   12868000 Jan 16 13:59  BBH_Classification_Model_5.h5
# -rw------- 1 root root    6396921 Jan 15 13:16  BBH_Classification_4.ckpt.data-00000-of-00001
# -rw------- 1 root root       4061 Jan 15 13:16  BBH_Classification_4.ckpt.index
# -rw------- 1 root root    6478872 Jan 15 13:16  BBH_Classification_Model_4.h5
# drwx------ 2 root root       4096 Jan 14 07:25 'FYP NBs'
# -rw------- 1 root root    3767216 Jan 13 09:10  BBH_Classification_Model_3.h5
# -rw------- 1 root root       3261 Jan 13 09:10  BBH_Classification_3.ckpt.index
# -rw------- 1 root root    3701371 Jan 13 09:10  BBH_Classification_3.ckpt.data-00000-of-00001
# ...

# %%
# training file locations
posvalfoldername = '/content/gdrive/MyDrive/Positive_Validation_DATA'
negvalfoldername = '/content/gdrive/MyDrive/Negative_Validation_DATA'

# postive and negative prefixes
posvalprefix = 110100000
negvalprefix = 100100000

#samples of pos and neg training data
posvalsamples = 3072
negvalsamples = 1024



# number of batches
# batch_looping_times = 64

# number of samples in each batch
val_samples=  posvalsamples +negvalsamples

print(val_samples)
val_y=np.concatenate((np.ones((posvalsamples, 1)), np.zeros((negvalsamples, 1))))
print(val_y.shape)
# Out:
# 4096
# (4096, 1)

# %%
def batchload_val():
  global val_y
  global val_samples
  # print(samples)
  X=np.zeros((val_samples,8192*2))
  # y=np.zeros((samples,1))
  for i in range(posvalsamples):
    posfile_name = posvalfoldername+'/'+str(posvalprefix+i+1)+'.npy'
    X[i] = np.load(posfile_name)
    # y[i] = 1
  for i in range(negvalsamples):
    negfile_name = negvalfoldername+'/'+str(negvalprefix+i+1)+'.npy'
    X[i+posvalsamples] = np.load(negfile_name)
    # y[i] = 0

  X = X.reshape(val_samples, 16384,1)
  
  return X, val_y

x_val, y_val = batchload_val()
x_val, y_val= shuffle(x_val, y_val, random_state=346)

# %%
from keras.models import load_model
model = load_model("/content/gdrive/MyDrive/BBH_Classification_Model_5.h5")
model.load_weights("/content/gdrive/My Drive/BBH_Classification_5.ckpt")
score = model.evaluate(x_val, y_val, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.060732800513505936
# Test accuracy: 0.982421875

# %%
from keras.models import load_model
model = load_model("/content/gdrive/MyDrive/BBH_Classification_Model_4.h5")
model.load_weights("/content/gdrive/My Drive/BBH_Classification_4.ckpt")
score = model.evaluate(x_val, y_val, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.08368976414203644
# Test accuracy: 0.97265625

# %%
from keras.models import load_model
model = load_model("/content/gdrive/MyDrive/BBH_Classification_Model_3.h5")
model.load_weights("/content/gdrive/My Drive/BBH_Classification_3.ckpt")
score = model.evaluate(x_val, y_val, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# Test loss: 0.09578469395637512
# Test accuracy: 0.967529296875

# %%
from keras.models import load_model
model = load_model("/content/gdrive/MyDrive/BBH_Classification_Model_2.h5")
model.load_weights("/content/gdrive/My Drive/BBH_Classification_2.ckpt")
score = model.evaluate(x_val, y_val, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.10585514456033707
# Test accuracy: 0.962646484375

# %%
from keras.models import load_model
model = load_model("/content/gdrive/MyDrive/BBH_Classification_Model.h5")
model.load_weights("/content/gdrive/My Drive/BBH_Classification.ckpt")
score = model.evaluate(x_val, y_val, verbose = 0) 

print('Test loss:', score[0]) 
print('Test accuracy:', score[1])
# Out:
# Test loss: 38.1667594909668
# Test accuracy: 0.75
